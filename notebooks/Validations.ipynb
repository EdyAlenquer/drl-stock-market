# %%
import sys
sys.path.append('..')

import pandas as pd

# %%
df = pd.read_pickle('../TUNING/PETR4/DDPG_HMAX_200_WITH_FUND/dataset.pkl')
df
# Out:
#             date   tic       open       high        low      close  \
# 0     2014-01-02  PETR  17.150000  17.200001  16.650000   9.715923
# 1     2014-01-03  PETR  16.740000  16.780001  16.410000   9.570910
# 2     2014-01-06  PETR  16.450001  16.639999  16.160000   9.640516
# 3     2014-01-07  PETR  16.650000  16.830000  16.120001   9.373690
# 4     2014-01-08  PETR  16.270000  16.389999  16.139999   9.391091
# ...          ...   ...        ...        ...        ...        ...
# 1932  2021-12-22  PETR  28.400000  28.400000  27.969999  23.098547
# 1933  2021-12-23  PETR  28.330000  28.420000  28.150000  23.237991
# 1934  2021-12-27  PETR  28.320000  28.780001  28.150000  23.582502
# 1935  2021-12-28  PETR  29.010000  29.280001  28.700001  23.607111
# 1936  2021-12-29  PETR  28.700001  28.900000  28.420000  23.410248
#
#           volume  day      macd    boll_ub  ...       P/L      P/EBITDA  \
# 0     17284800.0  3.0  0.000000   9.848497  ...  9.496954  2.666192e-07
# ...

# %%
df_copy = df.copy()
df_copy['date'] = df_copy['date'].shift(-20)
df_copy
# Out:
#             date   tic       open       high        low      close  \
# 0     2014-01-31  PETR  17.150000  17.200001  16.650000   9.715923
# 1     2014-02-03  PETR  16.740000  16.780001  16.410000   9.570910
# 2     2014-02-04  PETR  16.450001  16.639999  16.160000   9.640516
# 3     2014-02-05  PETR  16.650000  16.830000  16.120001   9.373690
# 4     2014-02-06  PETR  16.270000  16.389999  16.139999   9.391091
# ...          ...   ...        ...        ...        ...        ...
# 1932         NaN  PETR  28.400000  28.400000  27.969999  23.098547
# 1933         NaN  PETR  28.330000  28.420000  28.150000  23.237991
# 1934         NaN  PETR  28.320000  28.780001  28.150000  23.582502
# 1935         NaN  PETR  29.010000  29.280001  28.700001  23.607111
# 1936         NaN  PETR  28.700001  28.900000  28.420000  23.410248
#
#           volume  day      macd    boll_ub  ...       P/L      P/EBITDA  \
# 0     17284800.0  3.0  0.000000   9.848497  ...  9.496954  2.666192e-07
# ...
